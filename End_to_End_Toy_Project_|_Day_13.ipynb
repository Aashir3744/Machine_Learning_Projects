# %% [markdown]
# <a href="https://colab.research.google.com/github/Aashir3744/Machine_Learning_Projects/blob/main/End_to_End_Toy_Project_%7C_Day_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'], c = df['placement'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1]

# %%
X
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import  train_test_split

# %%
X_Train , X_Test, Y_Train, Y_Test = train_test_split(X,Y,test_size = 0.1)

# %%
X_Train
# Out:
#     cgpa     iq
# 35   6.8   90.0
# 43   6.8  141.0
# 26   7.0  199.0
# 30   7.6  128.0
# 23   4.7   87.0
# ..   ...    ...
# 64   7.0   64.0
# 77   7.3   50.0
# 92   5.2  110.0
# 16   5.2  224.0
# 13   6.4  116.0
#
# [90 rows x 2 columns]

# %%
X_Test
# Out:
#     cgpa     iq
# 96   4.4   42.0
# 22   4.9  120.0
# 10   6.0   45.0
# 4    5.8  142.0
# 0    6.8  123.0
# 25   5.0   91.0
# 74   6.7  154.0
# 70   6.3  127.0
# 8    6.1  156.0
# 20   6.6  120.0

# %%
Y_Train
# Out:
# 35    1
# 43    1
# 26    1
# 30    1
# 23    0
#      ..
# 64    1
# 77    1
# 92    0
# 16    0
# 13    1
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
X_Train = scalar.fit_transform(X_Train)

# %%
X_Train
# Out:
# array([[ 0.6793261 , -0.87913315],
#        [ 0.6793261 ,  0.40678819],
#        [ 0.85034526,  1.86920854],
#        [ 1.36340274,  0.07900432],
#        [-1.11637506, -0.95477559],
#        [ 1.27789316,  0.12943261],
#        [ 0.08075905, -0.55134928],
#        [-1.03086548, -0.32442199],
#        [ 0.16626863, -0.29920784],
#        [ 1.79095063,  0.60850134],
#        [ 0.42279736, -0.87913315],
#        [ 1.106874  , -0.22356541],
#        [ 0.08075905, -1.10606045],
#        [-0.9453559 ,  0.75978621],
#        [ 0.93585484,  0.65892963],
#        [ 0.76483568,  0.33114576],
#        [-0.68882717,  0.17986089],
#        [ 0.85034526,  1.26406908],
#        [ 0.6793261 , -0.32442199],
#        [ 1.106874  ,  0.30593161],
#        [-1.03086548,  1.11278422],
#        [ 1.79095063,  1.03714179],
#        [ 0.42279736,  0.88585693],
#        [-0.68882717, -0.87913315],
#        [-0.09026011, -0.47570685],
#        [ 1.27789316, -1.61034333],
#        [-0.68882717,  0.91107107],
#        [-0.00475053,  0.60850134],
#        [-1.71494212, -0.62699171],
#        [-1.11637506, -1.83727062],
#        [ 1.19238358,  0.17986089],
#        [-0.26127927,  0.45721648],
#        [-0.51780801, -0.45049271],
#        [ 0.50830694,  0.33114576],
#        [ 0.42279736, -2.21548278],
#        [-1.8004517 , -0.40006442],
#        [-2.14249001,  2.72648944],
#        [-0.00475053, -1.48427261],
#        [-1.71494212, -1.25734531],
#        [ 1.36340274, -0.9043473 ],
#        [ 0.85034526,  0.3563599 ],
#        [-0.60331759, -0.09749469],
#        [ 0.25177821, -0.55134928],
#        [-1.03086548,  0.96149936],
#        [ 1.53442189, -0.2739937 ],
#        [ 1.27789316,  0.83542864],
#        [-0.77433675,  1.28928323],
#        [-0.77433675, -1.48427261],
#        [ 0.76483568,  0.3563599 ],
#        [ 1.96196979,  1.08757008],
#        [ 1.106874  , -0.97998973],
#        [-0.26127927,  0.17986089],
#        [ 2.13298895, -0.12270883],
#        [-0.51780801, -0.2739937 ],
#        [-0.9453559 ,  1.79356611],
#        [ 0.08075905,  0.17986089],
#        [ 0.59381652,  1.44056809],
#        [-0.77433675,  0.07900432],
#        [-0.85984632, -1.55991504],
#        [ 0.25177821,  0.07900432],
#        [-0.9453559 , -1.61034333],
#        [-0.9453559 ,  0.23028918],
#        [ 0.33728778,  0.40678819],
#        [-1.20188464,  0.53285891],
#        [ 1.70544105, -1.15648874],
#        [-0.51780801,  0.3563599 ],
#        [-0.85984632, -0.17313712],
#        [-0.51780801,  0.25550333],
#        [-0.60331759, -0.2739937 ],
#        [-0.00475053, -0.57656343],
#        [ 0.85034526, -0.32442199],
#        [ 0.93585484, -1.9381272 ],
#        [-2.31350917,  1.46578224],
#        [-1.3729038 ,  0.60850134],
#        [-0.26127927,  1.11278422],
#        [-0.9453559 ,  0.65892963],
#        [-1.11637506, -0.09749469],
#        [-1.03086548,  0.40678819],
#        [ 0.76483568, -0.72784829],
#        [ 0.42279736,  0.12943261],
#        [-0.00475053, -0.02185226],
#        [ 0.08075905, -1.50948675],
#        [-0.17576969,  1.03714179],
#        [-1.45841338,  1.89442268],
#        [-0.26127927,  0.38157405],
#        [ 0.85034526, -1.5347009 ],
#        [ 1.106874  , -1.88769891],
#        [-0.68882717, -0.37485027],
#        [-0.68882717,  2.49956214],
#        [ 0.33728778, -0.22356541]])

# %%
X_Test = scalar.transform(X_Test)

# %%
X_Test
# Out:
# array([[-1.3729038 , -2.08941206],
#        [-0.9453559 , -0.12270883],
#        [-0.00475053, -2.01376963],
#        [-0.17576969,  0.43200233],
#        [ 0.6793261 , -0.0470664 ],
#        [-0.85984632, -0.85391901],
#        [ 0.59381652,  0.73457206],
#        [ 0.25177821,  0.05379017],
#        [ 0.08075905,  0.78500035],
#        [ 0.50830694, -0.12270883]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_Train,Y_Train)
# Out:
# LogisticRegression()

# %%
Y_Pred = clf.predict(X_Test)

# %%
Y_Test
# Out:
# 96    0
# 22    0
# 10    1
# 4     0
# 0     1
# 25    0
# 74    1
# 70    1
# 8     0
# 20    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_Test, Y_Pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_Train, Y_Train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open("Model.pkl", 'wb'))
